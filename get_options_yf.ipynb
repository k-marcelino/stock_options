# %%
# Imported libraries
import yfinance as yf
import pandas as pd

# %%
tick_amzn = yf.Ticker("AMZN") # Option Ticker
print(tick_amzn.options) # Option Expiration Dates
date = tick_amzn.options[-1] # Farest due date
print(date)
# Out:
# ('2022-12-02', '2022-12-09', '2022-12-16', '2022-12-23', '2022-12-30', '2023-01-20', '2023-02-17', '2023-03-17', '2023-04-21', '2023-06-16', '2023-07-21', '2023-09-15', '2023-10-20', '2024-01-19', '2024-06-21', '2025-01-17')
# 2025-01-17

# %%
tick_amzn.option_chain().puts
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   AMZN221202P00050000 2022-11-08 19:34:22+00:00    50.0       0.02   0.00
# 1   AMZN221202P00055000 2022-11-25 16:06:49+00:00    55.0       0.01   0.00
# 2   AMZN221202P00060000 2022-11-22 14:30:01+00:00    60.0       0.01   0.00
# 3   AMZN221202P00065000 2022-11-22 18:50:34+00:00    65.0       0.01   0.00
# 4   AMZN221202P00070000 2022-11-25 17:49:38+00:00    70.0       0.01   0.01
# ..                  ...                       ...     ...        ...    ...
# 70  AMZN221202P00141000 2022-11-03 14:00:31+00:00   141.0      49.90  47.20
# 71  AMZN221202P00145000 2022-10-18 13:30:22+00:00   145.0      26.37   0.00
# 72  AMZN221202P00150000 2022-11-08 15:02:55+00:00   150.0      60.00  56.20
# 73  AMZN221202P00155000 2022-10-26 13:35:15+00:00   155.0      39.05   0.00
# 74  AMZN221202P00160000 2022-10-21 16:41:32+00:00   160.0      42.65  65.65
#
# ...

# %%
call_data = tick_amzn.option_chain(date = date).calls  # Calls for a given date
call_data
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   AMZN250117C00050000 2022-11-25 17:49:08+00:00    50.0      52.73  52.00
# 1   AMZN250117C00055000 2022-11-25 17:55:50+00:00    55.0      48.75  48.50
# 2   AMZN250117C00060000 2022-11-25 16:27:06+00:00    60.0      45.30  43.60
# 3   AMZN250117C00065000 2022-11-25 15:35:35+00:00    65.0      42.20  40.65
# 4   AMZN250117C00070000 2022-11-25 17:55:01+00:00    70.0      38.53  38.00
# 5   AMZN250117C00075000 2022-11-25 17:27:51+00:00    75.0      35.90  34.50
# 6   AMZN250117C00080000 2022-11-25 15:58:03+00:00    80.0      32.80  31.55
# 7   AMZN250117C00085000 2022-11-25 16:38:20+00:00    85.0      29.91  29.25
# 8   AMZN250117C00090000 2022-11-25 17:47:41+00:00    90.0      27.50  27.00
# 9   AMZN250117C00095000 2022-11-25 17:37:28+00:00    95.0      25.11  24.75
# 10  AMZN250117C00100000 2022-11-25 17:58:46+00:00   100.0      23.45  22.15
# ...
